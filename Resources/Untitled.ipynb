# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
### Read csv
df = pd.read_csv("MRTS-clean.csv")
# Out:
# C:\Users\fhelm\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (1,2,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         cat_idx cat_code                                           cat_desc  \
# 0           1.0    44X72              44X72: Retail Trade and Food Services
# 1           2.0    44Y72     44Y72: Retail Trade and Food Services, ex Auto
# 2           3.0    44Z72      44Z72: Retail Trade and Food Services, ex Gas
# 3           4.0    44W72  44W72: Retail Trade and Food Services, ex Auto...
# 4           5.0    44000                                44000: Retail Trade
# ...         ...      ...                                                ...
# 165956      NaN      NaN                                                NaN
# 165957      NaN      NaN                                                NaN
# 165958      NaN      NaN                                                NaN
# 165959      NaN      NaN                                                NaN
# 165960      NaN      NaN                                                NaN
#
# ...

# %%
keys_df = df.pop('cat_idx', 'cat_code', 'cat_desc')
keys_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-32edde7bbd04> in <module>
# ----> 1 keys_df = df.pop('cat_idx', 'cat_code', 'cat_desc')
#       2 keys_df
#
# TypeError: pop() takes 2 positional arguments but 4 were given
